# %% [markdown]
# # Feature Engineering Exercises

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pydataset import data

import wrangle
import modeling
import evaluate

from sklearn.feature_selection import SelectKBest, f_regression, RFE
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Load the tips dataset.

# %%
swiss = data('swiss')

# %%
tips = data('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 1       16.99  1.01  Female     No  Sun  Dinner     2
# 2       10.34  1.66    Male     No  Sun  Dinner     3
# 3       21.01  3.50    Male     No  Sun  Dinner     3
# 4       23.68  3.31    Male     No  Sun  Dinner     2
# 5       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Create a column named price_per_person. This should be the total bill divided by the party size.

# %%
tips['price_per_person'] = tips['total_bill'] / tips['size']

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person
# 1       16.99  1.01  Female     No  Sun  Dinner     2          8.495000
# 2       10.34  1.66    Male     No  Sun  Dinner     3          3.446667
# 3       21.01  3.50    Male     No  Sun  Dinner     3          7.003333
# 4       23.68  3.31    Male     No  Sun  Dinner     2         11.840000
# 5       24.59  3.61  Female     No  Sun  Dinner     4          6.147500

# %% [markdown]
# Before using any of the methods discussed in the lesson, which features do you think would be most important for predicting the tip amount?

# %% [markdown]
# - I think the most important features will be number of people, total bill, and meal time.

# %% [markdown]
# Use select k best to select the top 2 features for predicting tip amount. What are they?

# %%
train, validate, test = wrangle.subset_df(tips)
train.shape, validate.shape, test.shape
# Out:
# ((146, 8), (49, 8), (49, 8))

# %%
X_train, y_train, X_validate, y_validate, X_test, y_test = modeling.xy_subsets(train, validate, test, 'tip')

# %%
X_train.head()
# Out:
#      total_bill     sex smoker   day    time  size  price_per_person
# 195       16.58    Male    Yes  Thur   Lunch     2          8.290000
# 77        17.92    Male    Yes   Sat  Dinner     2          8.960000
# 42        17.46    Male     No   Sun  Dinner     2          8.730000
# 109       18.24    Male     No   Sat  Dinner     2          9.120000
# 224       15.98  Female     No   Fri   Lunch     3          5.326667

# %%
mms = MinMaxScaler()
X_train[['total_bill', 'price_per_person']] = mms.fit_transform(train[['total_bill', 'price_per_person']])
X_train.head()
# Out:
#      total_bill     sex smoker   day    time  size  price_per_person
# 195    0.240346    Male    Yes  Thur   Lunch     2          0.311207
# 77     0.270084    Male    Yes   Sat  Dinner     2          0.349713
# 42     0.259876    Male     No   Sun  Dinner     2          0.336494
# 109    0.277186    Male     No   Sat  Dinner     2          0.358908
# 224    0.227031  Female     No   Fri   Lunch     3          0.140900

# %%
X_train = pd.get_dummies(X_train, columns=['sex', 'smoker', 'day', 'time', 'size'])

# %%
f_selector = SelectKBest(f_regression, k=2)
f_selector.fit(X_train, y_train)
# Out:
# SelectKBest(k=2, score_func=<function f_regression at 0x135d54af0>)

# %%
f_select_mask = f_selector.get_support()

# %%
X_train.iloc[:,f_select_mask]
# Out:
#      total_bill  size_2
# 195    0.240346       1
# 77     0.270084       1
# 42     0.259876       1
# 109    0.277186       1
# 224    0.227031       0
# 79     0.377497       1
# 145    0.237017       1
# 27     0.169108       1
# 236    0.095872       1
# 214    0.166889       1
# 184    0.386596       0
# 194    0.215934       1
# 1      0.249445       1
# 3      0.338660       0
# - The best two features using SelectKBest were total bill and whether or not the table size was 2 people

# %% [markdown]
# Use recursive feature elimination to select the top 2 features for tip amount. What are they?

# %%
X_train.head()
# Out:
#      total_bill  price_per_person  sex_Female  sex_Male  smoker_No  \
# 195    0.240346          0.311207           0         1          0
# 77     0.270084          0.349713           0         1          0
# 42     0.259876          0.336494           0         1          1
# 109    0.277186          0.358908           0         1          1
# 224    0.227031          0.140900           1         0          1
#
#      smoker_Yes  day_Fri  day_Sat  day_Sun  day_Thur  time_Dinner  time_Lunch  \
# 195           1        0        0        0         1            0           1
# 77            1        0        1        0         0            1           0
# 42            0        0        0        1         0            1           0
# 109           0        0        1        0         0            1           0
# 224           0        1        0        0         0            0           1
#
#      size_1  size_2  size_3  size_4  size_5  size_6
# 195       0       1       0       0       0       0
# 77        0       1       0       0       0       0
# 42        0       1       0       0       0       0
# 109       0       1       0       0       0       0
# 224       0       0       1       0       0       0

# %%
lm = LinearRegression()
rfe = RFE(lm, n_features_to_select=2)

rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=LinearRegression(), n_features_to_select=2)

# %%
ranks = rfe.ranking_
columns = X_train.columns.tolist()

feature_ranks = pd.DataFrame({'ranking': ranks,
                              'feature': columns})
feature_ranks.sort_values('ranking')
# Out:
#     ranking           feature
# 0         1        total_bill
# 1         1  price_per_person
# 16        2            size_5
# 12        3            size_1
# 13        4            size_2
# 17        5            size_6
# 2         6        sex_Female
# 14        7            size_3
# 11        8        time_Lunch
# 4         9         smoker_No
# 3        10          sex_Male
# 10       11       time_Dinner
# 9        12          day_Thur
# 5        13        smoker_Yes
# 8        14           day_Sun
# 15       15            size_4
# 6        16           day_Fri
# 7        17           day_Sat

# %% [markdown]
# - According to the RSE function, the two best features were price per person and total bill

# %% [markdown]
# Why do you think select k best and recursive feature elimination might give different answers for the top features? Does this change as you change the number of features you are selecting?

# %% [markdown]
# - I think the reason that the answers were different was because the SelectKBest function's answers were correlated to eachother, while the RSe functions were not. I'm unsure if this will change significantly as we change the number of features, but I would say that yes it probably does

# %% [markdown]
# Write a function named select_kbest that takes in the predictors (X), the target (y), and the number of features to select (k) and returns the names of the top k selected features based on the SelectKBest class. Test your function with the tips dataset. You should see the same results as when you did the process manually.

# %%
def select_kbest(X_train_scaled, y_train, k):
    
    f_selector = SelectKBest(f_regression, k=k)
    f_selector.fit(X_train_scaled, y_train)
    
    f_select_mask = f_selector.get_support()
    best_features = X_train_scaled.iloc[:,f_select_mask]
    
    return best_features.head(k)

# %%
select_kbest(X_train, y_train, 3)
# Out:
#      total_bill  size_2  size_4
# 195    0.240346       1       0
# 77     0.270084       1       0
# 42     0.259876       1       0
# 109    0.277186       1       0
# 224    0.227031       0       0
# 79     0.377497       1       0
# 145    0.237017       1       0
# 27     0.169108       1       0
# 236    0.095872       1       0
# 214    0.166889       1       0
# 184    0.386596       0       1
# 194    0.215934       1       0
# 1      0.249445       1       0
# 3      0.338660       0       0
# 78     0.476032       0       1
# 47     0.365735       1       0
# 101    0.124279       1       0
# 88     0.278074       1       0
# 203    0.160897       1       0
# 75     0.199290       1       0
# 215    0.497559       0       0
# 211    0.539503       0       0
# 122    0.170217       1       0
# 244    0.289170       1       0
# 21     0.270084       1       0
# 189    0.275189       0       0
# 72     0.251221       0       0
# 107    0.327119       1       0
# 15     0.201509       1       0
# 93     0.000000       1       0
# 180    0.640923       1       0
# 103    0.855526       0       0

# %% [markdown]
# Write a function named rfe that takes in the predictors, the target, and the number of features to select. It should return the top k features based on the RFE class. Test your function with the tips dataset. You should see the same results as when you did the process manually.

# %%
def rfe(X_train_scaled, y_train, n_features):
    
    lm = LinearRegression()
    rfe = RFE(lm, n_features_to_select=n_features)
    
    rfe.fit(X_train_scaled, y_train)
    
    ranks = rfe.ranking_
    columns = X_train_scaled.columns.tolist()
        
    feature_ranks = pd.DataFrame({'ranking': ranks,
                                  'feature': columns})
    feature_ranks = feature_ranks.sort_values('ranking')
    
    return feature_ranks.head(n_features)

# %% [markdown]
# Load the swiss dataset and use all the other features to predict Fertility. Find the top 3 features using both select k best and recursive feature elimination (use the functions you just built to help you out).

# %%
swiss.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality
# Courtelary                22.2
# Delemont                  22.2
# Franches-Mnt              20.2
# Moutier                   20.3
# Neuveville                20.6

# %%
train, validate, test = wrangle.subset_df(swiss)
train.shape, validate.shape, test.shape
# Out:
# ((28, 6), (9, 6), (10, 6))

# %%
cols_to_scale = ['Agriculture', 'Catholic', 'Infant.Mortality']

# %%
train_scaled, validate_scaled, test_scaled = wrangle.scale_data(train, validate, test, MinMaxScaler(), cols_to_scale)

# %%
train_scaled.head()
# Out:
#              Fertility  Agriculture  Examination  Education  Catholic  \
# Sarine            82.9     0.402685           16         13  0.911906
# Grandson          71.7     0.252349           17          8  0.011753
# Yverdon           65.4     0.460403           15          8  0.040368
# Herens            77.3     1.000000            5          2  1.000000
# Rive Droite       44.7     0.421477           16         29  0.493408
#
#              Infant.Mortality
# Sarine               0.860759
# Grandson             0.582278
# Yverdon              0.740506
# Herens               0.474684
# Rive Droite          0.468354

# %%
X_train, y_train, X_validate, y_validate, X_test, y_test = modeling.xy_subsets(train_scaled, validate_scaled, test_scaled, 'Fertility')

# %%
X_train.head()
# Out:
#              Agriculture  Examination  Education  Catholic  Infant.Mortality
# Sarine          0.402685           16         13  0.911906          0.860759
# Grandson        0.252349           17          8  0.011753          0.582278
# Yverdon         0.460403           15          8  0.040368          0.740506
# Herens          1.000000            5          2  1.000000          0.474684
# Rive Droite     0.421477           16         29  0.493408          0.468354

# %%
X_train = pd.get_dummies(X_train, columns=['Examination', 'Education'])

# %%
select_kbest(X_train, y_train, 3)
# Out:
#           Catholic  Infant.Mortality  Education_29
# Sarine    0.911906          0.860759             0
# Grandson  0.011753          0.582278             0
# Yverdon   0.040368          0.740506             0

# %%
rfe(X_train, y_train, 3)
# Out:
#     ranking         feature
# 32        1    Education_29
# 1         1        Catholic
# 10        1  Examination_15
